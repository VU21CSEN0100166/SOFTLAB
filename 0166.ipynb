# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time,a,b,c):
  temp=a*time**2+b*time+c
  return temp
a=0.5
b=-2
c=20
time_values=np.linspace(0,10,100)
y_values=quadratic_model(time_values,a,b,c)
plt.plot(time_values,y_values)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time,a,b,c):
  temp=a*time**2+b*time+c
  return temp
a=float(input("enter the value of a"))
b=float(input("enter the vaue of b"))
c=float(input("enter the value of c"))

time_values=np.linspace(0,10,100)
y_values=quadratic_model(time_values,a,b,c)
plt.plot(time_values,y_values)
plt.show()
# Out:
# enter the value of a0.5
# enter the vaue of b-2
# enter the value of c20

# %%
import matplotlib.pyplot as plt

def quadratic_weather_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    print("Quadratic Weather Modeling")
    print("==========================")

    try:
        with open('SingleValFile.txt', 'r') as file:
            lines = file.readlines()

        time_values = list(range(0, 11))
        plt.figure(figsize=(8, 6))

        for line in lines:
            coefficients = line.split()
            a, b, c = map(float, coefficients)

            temperature_values = [quadratic_weather_model(t, a, b, c) for t in time_values]

            plt.plot(time_values, temperature_values, marker='o', linestyle='-', label=f'a={a}, b={b}, c={c}')

        plt.title('Temperature Variation Over Time')
        plt.xlabel('Time')
        plt.ylabel('Temperature')
        plt.grid(True)
        plt.xlim(0, 10)
        plt.legend()
        plt.show()

    except FileNotFoundError:
        print("File not found. Please make sure 'SingleValFile.txt' exists.")

if __name__ == "__main__":
    main()
# Out:
# Quadratic Weather Modeling
# ==========================

# %%
import matplotlib.pyplot as plt

def quadratic_weather_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    print("Quadratic Weather Modeling")
    print("==========================")

    try:
        with open('MultiVarSet.txt', 'r') as file:
            lines = file.readlines()

        time_values = list(range(0, 11))
        plt.figure(figsize=(8, 6))

        for line in lines:
            coefficients = line.split()
            a, b, c = map(float, coefficients)

            temperature_values = [quadratic_weather_model(t, a, b, c) for t in time_values]

            plt.plot(time_values, temperature_values, marker='o', linestyle='-', label=f'a={a}, b={b}, c={c}')

        plt.title('Temperature Variation Over Time')
        plt.xlabel('Time')
        plt.ylabel('Temperature')
        plt.grid(True)
        plt.xlim(0, 10)
        plt.legend()
        plt.show()

    except FileNotFoundError:
        print("File not found. Please make sure 'MultiVarSet.txt' exists.")

if __name__ == "__main__":
    main()
# Out:
# Quadratic Weather Modeling
# ==========================

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get user input for the coefficients
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))

# Generate x values
x = np.linspace(-10, 10, 400)

# Calculate y values for the first function
y1 = a*x**2 + b*x + c

# Plot the first function
plt.plot(x, y1, label='user inputs')

# Hard-coded coefficients for the second function
a = 1
b = -5
c = 7

# Calculate y values for the second function
y2 = a*x**2 + b*x + c

# Plot the second function
plt.plot(x, y2, label='hardcord input')

# Add title, labels, legend, and grid
plt.title('Plot of the quadratic functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
# Out:
# Enter the value of a: 2
# Enter the value of b: -3
# Enter the value of c: 7
